# %%
# Analyse monthly sur 7 ans
# Analyse weekly sur 4 ans
# Analyse daily sur 6 mois

# %%
# %matplotlib inline
import pandas as pd
import mplfinance as mpf
import plotly.graph_objs as go

# %%
import stocks
start = "2000-01-01"
end = "2021-02-28"
ticker = "MSFT"          # Amazon
#ticker = "NTDOY"        # Nintendo
prices = stocks.GrabPrices(ticker, start, end)

# %%
prices
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2000-01-03   59.312500   56.000000   58.687500   58.281250  53228400.0
# 2000-01-04   58.562500   56.125000   56.781250   56.312500  54119000.0
# 2000-01-05   58.187500   54.687500   55.562500   56.906250  64059600.0
# 2000-01-06   56.937500   54.187500   56.093750   55.000000  54976600.0
# 2000-01-07   56.125000   53.656250   54.312500   55.718750  62013600.0
# ...                ...         ...         ...         ...         ...
# 2021-02-22  237.929993  232.399994  237.419998  234.509995  36446900.0
# 2021-02-23  234.830002  228.729996  230.330002  233.270004  30228700.0
# 2021-02-24  235.199997  229.000000  230.009995  234.550003  26339700.0
# 2021-02-25  234.589996  227.880005  232.080002  228.990005  39542200.0
# 2021-02-26  235.369995  229.539993  231.529999  232.380005  37811200.0
#
#              Adj Close
# Date
# 2000-01-03   37.017384
# 2000-01-04   35.766914
# 2000-01-05   36.144032
# 2000-01-06   34.933285
# 2000-01-07   35.389793
# ...                ...
# 2021-02-22  234.509995
# 2021-02-23  233.270004
# 2021-02-24  234.550003
# 2021-02-25  228.990005
# 2021-02-26  232.380005
#
# [5322 rows x 6 columns]

# %%
prices.shape
# Out:
# (5322, 6)

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5322 entries, 2000-01-03 to 2021-02-26
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       5322 non-null   float64
#  1   Low        5322 non-null   float64
#  2   Open       5322 non-null   float64
#  3   Close      5322 non-null   float64
#  4   Volume     5322 non-null   float64
#  5   Adj Close  5322 non-null   float64
# dtypes: float64(6)
# memory usage: 291.0 KB

# %%
prices.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
#mpf.plot(prices,volume=True, type='candle', tight_layout=True,
#         figratio=(20,12),
#         title='AMZN 2020',
#         mav=(30,100), 
#         style='yahoo')

# %%
rangestart = '2020'
rangeend   = '2021'
mpf.plot(prices.loc[rangestart:rangeend],volume=True, type='candle', tight_layout=True,
         figratio=(20,12),
         title=ticker + ' '+ rangestart + ':' + rangeend,
         mav=(30,100), 
         style='yahoo'
        )

# %%
import stocks
start = "2000-01-01"
end = "2021-02-28"
ticker = "MSFT"          # Amazon
#ticker = "NTDOY"        # Nintendo
prices = stocks.GrabPrices(ticker, start, end)

ss = prices.loc['2020-07':'2020-12']
mpf.plot(ss, type='candle', tight_layout=True,
         figratio=(25,15), style='yahoo')

# %%
ss.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
ss['High'].max()
# Out:
# 232.86000061035156

# %%
daterange = ss.loc['2020-07-01':'2020-07-30']
high = daterange['High'].max()
high
#ss[ss['High'].gt(225)]
# Out:
# 216.3800048828125

# %%
daterange = ss.loc['2020-07-01':'2020-07-30'].round(0)
#daterange[daterange['High'].gt(215)]
daterange[daterange['Close'].eq(daterange['High'])]
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2020-07-06  211.0  208.0  209.0  211.0  31897600.0      209.0
# 2020-07-08  213.0  209.0  210.0  213.0  33600000.0      211.0
# 2020-07-10  214.0  211.0  214.0  214.0  26177600.0      212.0
# 2020-07-20  212.0  203.0  205.0  212.0  36884800.0      210.0
# 2020-07-22  212.0  208.0  209.0  212.0  49605700.0      210.0
# 2020-07-27  204.0  201.0  201.0  204.0  30160900.0      202.0
# 2020-07-30  204.0  200.0  201.0  204.0  25079600.0      202.0

# %%
p = prices.round(0)
hammer = p['Close'].eq(p['High'])
prices['hammer'] = hammer
mpf.plot(prices.loc['2021-01':'2021-02'].round(0), type='candle', tight_layout=True,
         figratio=(25,15), style='yahoo')

# %%
prices[prices['hammer'] == True].round(1).tail(5)
# Out:
#              High    Low   Open  Close      Volume  Adj Close  hammer
# Date
# 2021-01-25  229.8  224.2  229.1  229.5  33152100.0      229.0    True
# 2021-02-12  245.3  242.7  243.9  245.0  16552000.0      244.4    True
# 2021-02-17  244.3  240.9  241.3  244.2  21653500.0      244.2    True
# 2021-02-18  243.9  240.9  241.8  243.8  16925600.0      243.8    True
# 2021-02-24  235.2  229.0  230.0  234.6  26339700.0      234.6    True

# %%
prices.round(0).tail(20)
# Out:
#              High    Low   Open  Close      Volume  Adj Close  hammer
# Date
# 2021-01-29  238.0  231.0  236.0  232.0  42468900.0      231.0   False
# 2021-02-01  242.0  232.0  235.0  240.0  33314200.0      239.0   False
# 2021-02-02  242.0  239.0  241.0  240.0  25916300.0      239.0   False
# 2021-02-03  245.0  239.0  240.0  243.0  27158100.0      242.0   False
# 2021-02-04  243.0  240.0  243.0  242.0  25296100.0      241.0   False
# 2021-02-05  243.0  240.0  242.0  242.0  18043900.0      242.0   False
# 2021-02-08  244.0  241.0  243.0  242.0  22211900.0      242.0   False
# 2021-02-09  245.0  241.0  242.0  244.0  23565000.0      243.0   False
# 2021-02-10  246.0  241.0  245.0  243.0  22186700.0      242.0   False
# 2021-02-11  245.0  242.0  245.0  244.0  15742200.0      244.0   False
# 2021-02-12  245.0  243.0  244.0  245.0  16552000.0      244.0    True
# 2021-02-16  246.0  243.0  245.0  244.0  26728500.0      243.0   False
# 2021-02-17  244.0  241.0  241.0  244.0  21653500.0      244.0    True
# 2021-02-18  244.0  241.0  242.0  244.0  16925600.0      244.0    True
# 2021-02-19  244.0  240.0  244.0  241.0  25262600.0      241.0   False
# 2021-02-22  238.0  232.0  237.0  235.0  36446900.0      235.0   False
# 2021-02-23  235.0  229.0  230.0  233.0  30228700.0      233.0   False
# 2021-02-24  235.0  229.0  230.0  235.0  26339700.0      235.0    True
# 2021-02-25  235.0  228.0  232.0  229.0  39542200.0      229.0   False
# 2021-02-26  235.0  230.0  232.0  232.0  37811200.0      232.0   False

# %% [markdown]
# # Multiplot trial

# %%
p1 = prices.copy()
#p1.index
first_trace = go.Candlestick(
    x     = p1.index,
    open  = p1.Open,
    high  = p1.High,
    low   = p1.Low,
    close = p1.Close )

# %%
p2 = prices.copy()
p2['Newcol'] = p2.Close-50

second_trace = go.Scatter(x=p2.index, y=p2.Newcol, mode='lines', name='Line')

# %%
data = [first_trace, second_trace]
layout = go.Layout(
    xaxis=dict(type='date'),
    yaxis=dict(title='Ticks')
)
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="d51fa8ea-cd96-4343-bf15-e5aace3ca3ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d51fa8ea-cd96-4343-bf15-e5aace3ca3ff")) {                    Plotly.newPlot(                        "d51fa8ea-cd96-4343-bf15-e5aace3ca3ff",                        [{"close": [58.28125, 56.3125, 56.90625, 55.0, 55.71875, 56.125, 54.6875, 52.90625, 53.90625, 56.125, 57.65625, 53.5, 53.0, 51.875, 50.625, 51.40625, 49.6875, 49.375, 49.125, 48.9375, 51.46875, 50.40625, 51.8125, 53.28125, 53.3125, 54.96875, 52.0, 53.0, 49.96875, 49.8125, 49.28125, 48.8125, 49.8125, 47.53125, 46.90625, 47.125, 47.375, 45.65625, 45.78125, 44.6875, 45.40625, 46.6875, 48.0625, 45.3125, 46.4375, 47.78125, 50.0, 50.5, 49.0, 47.5625, 47.6875, 47.6875, 49.6875, 48.6875, 51.375, 51.625, 55.9375, 55.84375, 52.03125, 52.15625, 53.59375, 51.6875, 53.125, 45.4375, 44.28125, 43.1875, 43.0, 44.53125, 43.03125, 41.9375, 39.6875, 39.625, 37.0625, 37.9375, 40.28125, 39.34375, 39.46875, 33.3125, 34.6875, 34.0, 34.90625, 34.875, 36.71875, 34.9375, 35.28125, 35.21875, 35.5625, 34.90625, 33.90625, 33.09375, 33.9375, 34.40625, 34.6875, 34.75, 33.84375, 33.09375, 32.53125, 32.09375, 31.59375, 32.78125, 30.75, 30.71875, 31.6875, 31.28125, 32.28125, 33.15625, 33.4375, 34.8125, 35.25, 34.40625, 34.40625, 33.4375, 33.9375, 35.25, 36.1875, 36.28125, 36.84375, 37.46875, 40.34375, 39.9375, 38.84375, 39.75, 39.40625, 39.46875, 38.59375, 40.0, 40.0, 39.25, 40.46875, 41.0, 39.71875, 39.5625, 40.15625, 39.96875, 39.46875, 39.09375, 39.25, 